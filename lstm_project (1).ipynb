# %%
faqs = """anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic institutions anarchists advocate social relations based upon voluntary association of autonomous individuals mutual aid and self governance while anarchism is most easily defined by what it is against anarchists also offer positive visions of what they believe to be a truly free society however ideas about how an anarchist society might work vary considerably especially with respect to economics there is also disagreement about how a free society might be brought about origins and predecessors kropotkin and others argue that before recorded history human society was organized on anarchist principles most anthropologists follow kropotkin and engels in believing that hunter gatherer bands were egalitarian and lacked division of labour accumulated wealth or decreed law and had equal access to resources william godwin anarchists including the the anarchy organisation and rothbard find anarchist attitudes in taoism from ancient china kropotkin found similar ideas in stoic zeno of citium according to kropotkin zeno repudiated the omnipotence of the state its intervention and regimentation and proclaimed the sovereignty of the moral law of the individual the anabaptists of one six th century europe are sometimes considered to be religious forerunners of modern anarchism bertrand russell in his history of western philosophy writes that the anabaptists repudiated all law since they held that the good man will be guided at every moment by the holy spirit from this premise they arrive at communism the diggers or true levellers were an early communistic movement during the time of the english civil war and are considered by some as forerunners of modern anarchism in the modern era the first to use the term to mean something other than chaos was louis armand baron de lahontan in his nouveaux voyages dans l am rique septentrionale one seven zero three where he described the indigenous american society which had no state laws prisons priests or private property as being in anarchy russell means a libertarian and leader in the american indian movement has repeatedly stated that he is an anarchist and so are all his ancestors in one seven nine three in the thick of the french revolution william godwin published an enquiry concerning political justice although godwin did not use the word anarchism many later anarchists have regarded this book as the first major anarchist text and godwin as the founder of philosophical anarchism but at this point no anarchist movement yet existed and the term anarchiste was known mainly as an insult hurled by the bourgeois girondins at more radical elements in the french revolution the first self labelled anarchist pierre joseph proudhon it is commonly held that it wasn t until pierre joseph proudhon published what is property in one eight four zero that the term anarchist was adopted as a self description it is for this reason that some claim proudhon as the founder of modern anarchist theory in what is property proudhon answers with the famous accusation property is theft in this work he opposed the institution of decreed property propri t where owners have complete rights to use and abuse their property as they wish such as exploiting workers for profit in its place proudhon supported what he called possession individuals can have limited rights to use resources capital and goods in accordance with principles of equality and justice proudhon s vision of anarchy which he called mutualism mutuellisme involved an exchange economy where individuals and groups could trade the products of their labor using labor notes which represented the amount of working time involved in production this would ensure that no one would profit from the labor of others workers could freely join together in co operative workshops an interest free bank would be set up to provide everyone with access to the means of production proudhon s ideas were influential within french working class movements and his followers were active in the revolution of one eight four eight in france proudhon s philosophy of property is complex it was developed in a number of works over his lifetime"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 385

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  10, 131],
#        [  0,   0,   0, ...,  10, 131,   5],
#        [  0,   0,   0, ..., 131,   5,   9],
#        ...,
#        [  0,   0,  10, ...,   2, 383, 384],
#        [  0,  10, 131, ..., 383, 384,  28],
#        [ 10, 131,   5, ..., 384,  28, 385]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (824, 824)

# %%
y.shape
# Out:
# (824,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=386)

# %%
y.shape
# Out:
# (824, 386)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(386, 100, input_length=824))
model.add(LSTM(150))
model.add(Dense(386, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 824, 100)          38600
#
#  lstm_4 (LSTM)               (None, 150)               150600
#
#  dense_4 (Dense)             (None, 386)               58286
#
# =================================================================
# Total params: 247486 (966.74 KB)
# Trainable params: 247486 (966.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 40s 1s/step - loss: 5.8735 - accuracy: 0.0316
# Epoch 2/100
# 26/26 [==============================] - 37s 1s/step - loss: 5.5679 - accuracy: 0.0595
# Epoch 3/100
# 26/26 [==============================] - 37s 1s/step - loss: 5.4750 - accuracy: 0.0595
# Epoch 4/100
# 26/26 [==============================] - 37s 1s/step - loss: 5.4482 - accuracy: 0.0595
# Epoch 5/100
# 26/26 [==============================] - 37s 1s/step - loss: 5.4302 - accuracy: 0.0595
# Epoch 6/100
# 26/26 [==============================] - 38s 1s/step - loss: 5.4071 - accuracy: 0.0595
# Epoch 7/100
# 26/26 [==============================] - 39s 2s/step - loss: 5.3623 - accuracy: 0.0595
# Epoch 8/100
# 26/26 [==============================] - 40s 2s/step - loss: 5.2911 - accuracy: 0.0667
# Epoch 9/100
# 26/26 [==============================] - 38s 1s/step - loss: 5.1497 - accuracy: 0.0850
# Epoch 10/100
# 26/26 [==============================] - 38s 1s/step - loss: 4.9479 - accuracy: 0.1117
# Epoch 11/100
# 26/26 [==============================] - 38s 1s/step - loss: 4.7057 - accuracy: 0.1444
# Epoch 12/100
# 26/26 [==============================] - 37s 1s/step - loss: 4.4198 - accuracy: 0.1590
# Epoch 13/100
# 26/26 [==============================] - 38s 1s/step - loss: 4.1391 - accuracy: 0.1626
# Epoch 14/100
# 26/26 [==============================] - 38s 1s/step - loss: 3.8486 - accuracy: 0.2015
# Epoch 15/100
# 26/26 [==============================] - 37s 1s/step - loss: 3.5651 - accuracy: 0.2269
# Epoch 16/100
# 26/26 [==============================] - 37s 1s/step - loss: 3.2981 - accuracy: 0.2621
# Epoch 17/100
# 26/26 [==============================] - 38s 1s/step - loss: 3.0210 - accuracy: 0.3022
# Epoch 18/100
#  8/26 [========>.....................] - ETA: 26s - loss: 2.7027 - accuracy: 0.4258

# %%
import numpy as np

# %%
import time
text = "i am"

for i in range(100):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=62, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# i am nick
# 1/1 [==============================] - 0s 33ms/step
# i am nick gets
# 1/1 [==============================] - 0s 44ms/step
# i am nick gets to
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is
# 1/1 [==============================] - 0s 40ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in
# 1/1 [==============================] - 0s 43ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went
# 1/1 [==============================] - 0s 44ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed
# 1/1 [==============================] - 0s 52ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with
# 1/1 [==============================] - 0s 38ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming
# 1/1 [==============================] - 0s 43ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back
# 1/1 [==============================] - 0s 54ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan
# 1/1 [==============================] - 0s 44ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom
# 1/1 [==============================] - 0s 42ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in
# 1/1 [==============================] - 0s 53ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west
# 1/1 [==============================] - 0s 34ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy
# 1/1 [==============================] - 0s 34ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area
# 1/1 [==============================] - 0s 48ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's
# 1/1 [==============================] - 0s 33ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy
# 1/1 [==============================] - 0s 53ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east
# 1/1 [==============================] - 0s 52ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg
# 1/1 [==============================] - 0s 33ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who
# 1/1 [==============================] - 0s 57ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is
# 1/1 [==============================] - 0s 53ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former
# 1/1 [==============================] - 0s 35ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate
# 1/1 [==============================] - 0s 46ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of
# 1/1 [==============================] - 0s 33ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in
# 1/1 [==============================] - 0s 49ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and
# 1/1 [==============================] - 0s 35ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows
# 1/1 [==============================] - 0s 32ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the
# 1/1 [==============================] - 0s 52ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the
# 1/1 [==============================] - 0s 41ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the young
# 1/1 [==============================] - 0s 29ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the young and
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the young and mysterious
# 1/1 [==============================] - 0s 55ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the young and mysterious millionaire
# 1/1 [==============================] - 0s 30ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the young and mysterious millionaire jay
# 1/1 [==============================] - 0s 33ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the young and mysterious millionaire jay gatsby
# 1/1 [==============================] - 0s 31ms/step
# i am nick gets to know gatsby better he learns that gatsby is deeply in love with daisy whom he met years ago before he went off to war gatsby is obsessed with the idea of reclaiming daisy's love and winning her back from tom buchanan buchanan tom buchanan egg a small house in west egg a wealthy area populated by the nick's cousin daisy buchanan lives nearby in east egg with her husband tom who is a former college classmate of nick's nick's nick's cousin in long island and follows the life of the young and mysterious millionaire jay gatsby he

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'of': 3,
#  'gatsby': 4,
#  'is': 5,
#  'a': 6,
#  'in': 7,
#  'his': 8,
#  'to': 9,
#  'he': 10,
#  'with': 11,
#  'novel': 12,
#  'by': 13,
#  'american': 14,
#  'nick': 15,
#  'who': 16,
#  'wealth': 17,
#  'as': 18,
#  'love': 19,
#  'its': 20,
#  'great': 21,
#  'it': 22,
#  'long': 23,
#  'island': 24,
#  'mysterious': 25,
#  'jay': 26,
#  'war': 27,
#  'about': 28,
#  'egg': 29,
#  "nick's": 30,
#  'daisy': 31,
#  'buchanan': 32,
#  'lives': 33,
#  'her': 34,
#  'tom': 35,
#  'becomes': 36,
#  'themes': 37,
#  'jazz': 38,
#  'age': 39,
#  'author': 40,
#  'f': 41,
#  'scott': 42,
#  'fitzgerald': 43,
#  'was': 44,
#  'first': 45,
#  'published': 46,
#  '1925': 47,
#  'set': 48,
#  'summer': 49,
#  '1922': 50,
#  'story': 51,
#  'primarily': 52,
#  'takes': 53,
#  'place': 54,
#  'new': 55,
#  'york': 56,
#  'follows': 57,
#  'life': 58,
#  'young': 59,
#  'millionaire': 60,
#  'narrated': 61,
#  'carraway': 62,
#  'yale': 63,
#  'graduate': 64,
#  'world': 65,
#  'i': 66,
#  'veteran': 67,
#  'moves': 68,
#  'learn': 69,
#  'bond': 70,
#  'business': 71,
#  'rents': 72,
#  'small': 73,
#  'house': 74,
#  'west': 75,
#  'wealthy': 76,
#  'area': 77,
#  'populated': 78,
#  'nouveau': 79,
#  'riche': 80,
#  'cousin': 81,
#  'nearby': 82,
#  'east': 83,
#  'husband': 84,
#  'former': 85,
#  'college': 86,
#  'classmate': 87,
#  'soon': 88,
#  'acquainted': 89,
#  'enigmatic': 90,
#  'neighbor': 91,
#  'throws': 92,
#  'lavish': 93,
#  'parties': 94,
#  'every': 95,
#  'weekend': 96,
#  'at': 97,
#  'mansion': 98,
#  'despite': 99,
#  'extravagant': 100,
#  'lifestyle': 101,
#  'remains': 102,
#  'aloof': 103,
#  'rumors': 104,
#  'abound': 105,
#  'past': 106,
#  'source': 107,
#  'gets': 108,
#  'know': 109,
#  'better': 110,
#  'learns': 111,
#  'that': 112,
#  'deeply': 113,
#  'whom': 114,
#  'met': 115,
#  'years': 116,
#  'ago': 117,
#  'before': 118,
#  'went': 119,
#  'off': 120,
#  'obsessed': 121,
#  'idea': 122,
#  'reclaiming': 123,
#  "daisy's": 124,
#  'winning': 125,
#  'back': 126,
#  'from': 127,
#  'explores': 128,
#  'class': 129,
#  'dream': 130,
#  'portrays': 131,
#  'hedonistic': 132,
#  'excesses': 133,
#  'moral': 134,
#  'decay': 135,
#  'lurking': 136,
#  'beneath': 137,
#  'surface': 138,
#  'roaring': 139,
#  'twenties': 140,
#  "gatsby's": 141,
#  'pursuit': 142,
#  'status': 143,
#  'ultimately': 144,
#  'leads': 145,
#  'downfall': 146,
#  'victim': 147,
#  'own': 148,
#  'illusions': 149,
#  'corrupt': 150,
#  'society': 151,
#  'which': 152,
#  'widely': 153,
#  'regarded': 154,
#  'masterpiece': 155,
#  'literature': 156,
#  'considered': 157,
#  'one': 158,
#  'greatest': 159,
#  'novels': 160,
#  'ever': 161,
#  'written': 162,
#  'vivid': 163,
#  'depiction': 164,
#  'timeless': 165,
#  'continue': 166,
#  'resonate': 167,
#  'readers': 168,
#  'nearly': 169,
#  'century': 170,
#  'after': 171,
#  'publication': 172}
